# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/supriya-006/FlyRank_Assignment/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **My lane: Querying Big Data**
#
# I chose the Querying Big Data lane because I want to learn how to work with large-scale datasets efficiently by extracting only the information needed for analysis instead of downloading and processing the entire dataset. This approach helps in solving real-world data problems where datasets are too large to handle locally. My goal is to explore meaningful patterns, generate useful statistics, and support better decision-making through data-driven insights.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **The Question: Decision, Action, Cost of a Wrong Call**
#
# My work aims to improve data-driven decision-making by identifying useful patterns and insights from large datasets through efficient querying. The decision-makers can use these insights to understand trends, prioritize important areas, and make better strategic decisions. A wrong recommendation could lead to inefficient resource allocation, missed opportunities, wasted time, and incorrect business decisions.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **Quick look at the data**
#
# After loading the starter dataset, I explored a few basic statistics to understand whether querying large-scale data is valuable for this problem. The initial analysis showed important patterns in the dataset, such as the total number of records, the number of unique entities, and key metric distributions. These early numbers indicate that the dataset contains enough information and scale to investigate meaningful insights over the next 7 weeks.

# %%
import pandas as pd

df = pd.read_csv("/content/sample_data/california_housing_train.csv")

print("Total records:", len(df))
print("Number of features:", df.shape[1])
print("Average house value:", df["median_house_value"].mean())
# Out:
# Total records: 17000
# Number of features: 9
# Average house value: 207300.91235294117

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Careful words: what I can and can't claim
#
# My work will be able to identify patterns, trends, and relationships observed from the dataset through efficient querying and analysis. It can provide directional insights and decision support by helping users understand important factors and make more informed choices.
#
# However, this work will not prove causal relationships, meaning it cannot confirm that one factor directly causes another. It will also not claim to perfectly predict future outcomes or make guaranteed predictions about real-world events. The results should be used as analytical support rather than absolute answers.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
